# %%
import pickle
import pandas as pd
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
wine_df = pd.read_pickle("../wine_df.pickle")
wine_df
# Out:
#                                                     Wine  \
# 0      San Pedro de Yacochuya 'Yacochuya', Cafayate, ...
# 1      Michel Torino - El Esteco 'Don David' Reserve ...
# 2      Bodega Amalaya Malbec, Calchaqui Valley, Argen...
# 3      Bodega Colome Estate Torrontes, Calchaqui Vall...
# 4      Piattelli Vineyards Reserve Malbec, Cafayate, ...
# ...                                                  ...
# 54583  Backwards Distilling Company 'Contortionist' G...
# 54584  Roadhouse Brewing Co. 'Avarice & Greed' Golden...
# 54585  Melvin Brewing 'Hop Shocker' Imperial IPA Beer...
# 54586  Melvin Brewing Heyzeus Mexican Style Lager Bee...
# 54587  Melvin Brewing 'Tropical Lampin' Hazy IPA Beer...
#
#                             Region Subregion Appellation Vineyard      Grape  \
# 0      Cafayate - Calchaqui Valley       NaN         NaN      NaN     Malbec
# 1      Cafayate - Calchaqui Valley       NaN         NaN      NaN     Malbec
# ...
